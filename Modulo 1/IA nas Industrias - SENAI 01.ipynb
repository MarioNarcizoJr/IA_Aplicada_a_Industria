# %% [markdown]
# **ANÁLISE DE ITENS DENTRO DE UM DICIONÁRIO COM QUANTIDADES MAIOR QUE 2**

# %%
dados = {"bomba d'água": 3, "pressostato": 2, "sensor de temperatura": 6}
for item, quantidade in dados.items():
  if quantidade > 2:
    print(item)
# Out:
# bomba d'água
# sensor de temperatura

# %% [markdown]
# **REMOVER DUPLICIDADE EM LISTAS**

# %%
manutencoes = ["motor", "sensor", "válvula", "motor"]
manutencoes_unique = []

for item in manutencoes:
  if item not in manutencoes_unique:
    manutencoes_unique.append(item)

print(manutencoes_unique)
# Out:
# ['motor', 'sensor', 'válvula']

# %%
manutencoes = ["motor", "sensor", "válvula", "motor"]
unicos = set(manutencoes)
print(unicos)
# Out:
# {'sensor', 'motor', 'válvula'}

# %% [markdown]
# **IMPRIMIR TODOS OS VALORES DE UM DICIONARIO**

# %%
dados = {"01/06": "válvula", "02/06": "sensor", "03/06": "motor"}

for data,item in dados.items():
  print(item)
# Out:
# válvula
# sensor
# motor

# %%
dados = {"01/06": "válvula", "02/06": "sensor", "03/06": "motor"}

for dados in dados.values():
  print(dados)
# Out:
# válvula
# sensor
# motor

# %% [markdown]
# **CÁLCULO DE DETERMINANTE**

# %%
import numpy as np

mat = np.array([[3,2,3],[4,11,6],[7,8,9]])
mat2 = np.linalg.det(mat)
print(mat)

print("\nO cálculo de determinante da matriz acima é:", round(mat2))
# Out:
# [[ 3  2  3]
#  [ 4 11  6]
#  [ 7  8  9]]
#
# O cálculo de determinante da matriz acima é: 30

# %% [markdown]
# **ANALISE EXPLOTATORIA**

# %%
# !pip install pandas matplotlib seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **UTILIZAÇÃO DE DATAFRAME**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

dados_producao_vacinas = {
    'data': ['2025-05-01', '2025-05-01', '2025-05-02', '2025-05-02', '2025-05-03'],
    'turno': ['Manhã', 'Tarde', 'Manhã', 'Tarde', 'Manhã'],
    'temperatura_reator': [75.2, 76.1, 74.9, 75.5, 76.0],
    'concentracao_reagente': [0.98, 0.97, 0.99, 0.98, 0.97],
    'pureza_final': [99.5, 98.8, 99.7, 99.0, 99.2]
}

df_vacinas = pd.DataFrame(dados_producao_vacinas)
print(df_vacinas)
# Out:
#          data  turno  temperatura_reator  concentracao_reagente  pureza_final
# 0  2025-05-01  Manhã                75.2                   0.98          99.5
# 1  2025-05-01  Tarde                76.1                   0.97          98.8
# 2  2025-05-02  Manhã                74.9                   0.99          99.7
# 3  2025-05-02  Tarde                75.5                   0.98          99.0
# 4  2025-05-03  Manhã                76.0                   0.97          99.2

# %%
print(df_vacinas.head())
# Out:
#          data  turno  temperatura_reator  concentracao_reagente  pureza_final
# 0  2025-05-01  Manhã                75.2                   0.98          99.5
# 1  2025-05-01  Tarde                76.1                   0.97          98.8
# 2  2025-05-02  Manhã                74.9                   0.99          99.7
# 3  2025-05-02  Tarde                75.5                   0.98          99.0
# 4  2025-05-03  Manhã                76.0                   0.97          99.2

# %%
print(df_vacinas.tail())
# Out:
#          data  turno  temperatura_reator  concentracao_reagente  pureza_final
# 0  2025-05-01  Manhã                75.2                   0.98          99.5
# 1  2025-05-01  Tarde                76.1                   0.97          98.8
# 2  2025-05-02  Manhã                74.9                   0.99          99.7
# 3  2025-05-02  Tarde                75.5                   0.98          99.0
# 4  2025-05-03  Manhã                76.0                   0.97          99.2

# %%
print(df_vacinas.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   data                   5 non-null      object
#  1   turno                  5 non-null      object
#  2   temperatura_reator     5 non-null      float64
#  3   concentracao_reagente  5 non-null      float64
#  4   pureza_final           5 non-null      float64
# dtypes: float64(3), object(2)
# memory usage: 332.0+ bytes
# None

# %%
print(df_vacinas.describe())
# Out:
#        temperatura_reator  concentracao_reagente  pureza_final
# count            5.000000               5.000000      5.000000
# mean            75.540000               0.978000     99.240000
# std              0.512835               0.008367      0.364692
# min             74.900000               0.970000     98.800000
# 25%             75.200000               0.970000     99.000000
# 50%             75.500000               0.980000     99.200000
# 75%             76.000000               0.980000     99.500000
# max             76.100000               0.990000     99.700000

# %%
plt.figure(figsize=(8, 6))
df_vacinas.plot(kind='bar', color='lightblue')
plt.title('Pureza Média dos Componentes por Turno')
plt.xlabel('Turno')
plt.ylabel('Pureza Média (%)')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
sns.set_theme(style="whitegrid") # Define um estilo de tema para o Seaborn

# Calculate the mean pureza_final for each turno
pureza_por_turno = df_vacinas.groupby('turno')['pureza_final'].mean().reset_index()

plt.figure(figsize=(8, 6))
sns.barplot(x='turno', y='pureza_final', hue='turno', data=pureza_por_turno, palette="pastel", legend=False)
plt.title('Pureza Média dos Componentes por Turno (Estilizado com Seaborn)')
plt.xlabel('Turno')
plt.ylabel('Pureza Média (%)')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# **SCIKIT LEARNING**

# %%
# Importando as bibliotecas necessárias
import pandas as pd  # pandas é usado para manipular dados em tabelas (DataFrame)
from sklearn.model_selection import train_test_split  # para dividir os dados em treino e teste
from sklearn.tree import DecisionTreeClassifier       # o algoritmo de Árvore de Decisão
from sklearn.metrics import accuracy_score            # para calcular a acurácia do modelo

# Criando um DataFrame com dados fictícios de uma clínica
# Cada linha representa um agendamento de consulta
# As colunas são:
# - horario: hora do atendimento (ex: 8, 9, 10, 14...)
# - dia_semana: dia da semana (0=segunda, 1=terça,...)
# - faixa_etaria: grupo etário do paciente (1=jovem, 2=adulto, 3=idoso)
# - mensagem: se recebeu mensagem lembrando da consulta (1=sim, 0=não)
# - primeira_consulta: se é a primeira consulta (1=sim, 0=não)
# - compareceu: se o paciente compareceu ou não (1=sim, 0=não)

dados = pd.DataFrame({
    'horario': [8, 9, 10, 14, 15, 16],
    'dia_semana': [0, 1, 1, 3, 4, 5],
    'faixa_etaria': [1, 2, 3, 2, 1, 3],
    'mensagem': [1, 0, 1, 1, 0, 0],
    'primeira_consulta': [0, 1, 0, 0, 1, 1],
    'compareceu': [1, 0, 1, 1, 0, 0]
})

# Separando as variáveis independentes (X) e a variável alvo (y)
X = dados.drop('compareceu', axis=1)  # X são todas as colunas exceto 'compareceu'
y = dados['compareceu']                # y é apenas a coluna 'compareceu'

# Dividindo os dados em conjunto de treino e conjunto de teste
# 70% para treino e 30% para teste
X_treino, X_teste, y_treino, y_teste = train_test_split(X, y, test_size=0.3, random_state=42)

# Criando o modelo de Árvore de Decisão
modelo = DecisionTreeClassifier()

# Treinando o modelo com os dados de treino
modelo.fit(X_treino, y_treino)

# Fazendo previsões no conjunto de teste
previsoes = modelo.predict(X_teste)

# Calculando a acurácia do modelo (quantas previsões o modelo acertou em relação ao total)
print("Acurácia do modelo:", accuracy_score(y_teste, previsoes))
# Out:
# Acurácia do modelo: 0.5
