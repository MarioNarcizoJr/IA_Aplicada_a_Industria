# %% [markdown]
# #Atividade 01 - Módulo 4 - Mário Narcizo

# %%
# Baixa uma imagem de teste (test.jpg) do repositório de introdução ao OpenCV
# !wget -- no-check-certificate \
https://raw.githubusercontent.com/computationalcore/introduction-to-opencv/master/assets/test.jpg \
-0 test.jpg

# Baixa o classificador Haarcascade para detecção de rostos frontais
# !wget -- no-check-certificate \
https://raw.githubusercontent.com/computationalcore/introduction-to-opencv/master/assets/haarcascade_frontalface_default.xml \
-0 haarcascade_frontalface_default.xml

# Baixa um script auxiliar (common.py) com funções de apoio (carregar/exibir imagens, etc.)
# !wget -- no-check-certificate \
https://raw.githubusercontent.com/computationalcore/introduction-to-opencv/master/utils/common.py \
-O common.py
# Out:
# --2026-03-31 00:35:44--  http://no-check-certificate/
# Resolving no-check-certificate (no-check-certificate)... failed: Name or service not known.
# wget: unable to resolve host address ‘no-check-certificate’
# --2026-03-31 00:35:44--  https://raw.githubusercontent.com/computationalcore/introduction-to-opencv/master/assets/test.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 240458 (235K) [image/jpeg]
# Saving to: ‘test.jpg’
#
# test.jpg            100%[===================>] 234.82K  --.-KB/s    in 0.03s
#
# 2026-03-31 00:35:44 (8.68 MB/s) - ‘test.jpg’ saved [240458/240458]
#
# --2026-03-31 00:35:44--  http://-0/
# Resolving -0 (-0)... failed: Name or service not known.
# wget: unable to resolve host address ‘-0’
# --2026-03-31 00:35:44--  http://test.jpg/
# Resolving test.jpg (test.jpg)... failed: Name or service not known.
# wget: unable to resolve host address ‘test.jpg’
# FINISHED --2026-03-31 00:35:44--
# Total wall clock time: 0.3s
# Downloaded: 1 files, 235K in 0.03s (8.68 MB/s)
# --2026-03-31 00:35:44--  http://no-check-certificate/
# Resolving no-check-certificate (no-check-certificate)... failed: Name or service not known.
# wget: unable to resolve host address ‘no-check-certificate’
# --2026-03-31 00:35:44--  https://raw.githubusercontent.com/computationalcore/introduction-to-opencv/master/assets/haarcascade_frontalface_default.xml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 930127 (908K) [text/plain]
# Saving to: ‘haarcascade_frontalface_default.xml’
#
# haarcascade_frontal 100%[===================>] 908.33K  --.-KB/s    in 0.05s
#
# 2026-03-31 00:35:44 (19.3 MB/s) - ‘haarcascade_frontalface_default.xml’ saved [930127/930127]
#
# --2026-03-31 00:35:44--  http://-0/
# Resolving -0 (-0)... failed: Name or service not known.
# wget: unable to resolve host address ‘-0’
# --2026-03-31 00:35:44--  http://haarcascade_frontalface_default.xml/
# Resolving haarcascade_frontalface_default.xml (haarcascade_frontalface_default.xml)... failed: Name or service not known.
# wget: unable to resolve host address ‘haarcascade_frontalface_default.xml’
# FINISHED --2026-03-31 00:35:44--
# Total wall clock time: 0.2s
# Downloaded: 1 files, 908K in 0.05s (19.3 MB/s)
# --2026-03-31 00:35:45--  http://no-check-certificate/
# Resolving no-check-certificate (no-check-certificate)... failed: Name or service not known.
# wget: unable to resolve host address ‘no-check-certificate’
# --2026-03-31 00:35:45--  https://raw.githubusercontent.com/computationalcore/introduction-to-opencv/master/utils/common.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6572 (6.4K) [text/plain]
# Saving to: ‘common.py’
#
# common.py           100%[===================>]   6.42K  --.-KB/s    in 0s
#
# 2026-03-31 00:35:45 (44.0 MB/s) - ‘common.py’ saved [6572/6572]
#
# --2026-03-31 00:35:45--  http://-o/
# Resolving -o (-o)... failed: Name or service not known.
# wget: unable to resolve host address ‘-o’
# --2026-03-31 00:35:45--  http://common.py/
# Resolving common.py (common.py)... failed: Name or service not known.
# wget: unable to resolve host address ‘common.py’
# FINISHED --2026-03-31 00:35:45--
# Total wall clock time: 0.3s
# Downloaded: 1 files, 6.4K in 0s (44.0 MB/s)

# %% [markdown]
# #Importações

# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# #Leitura das Imagens

# %%
imagem = cv2.imread('test.jpg')
imagem_cinza = cv2.cvtColor(imagem, cv2.COLOR_BGR2GRAY)

plt.imshow(cv2.cvtColor(imagem, cv2.COLOR_BGR2RGB))

# %% [markdown]
# #Utilizando Modelo Pré-Treinado

# %%
imagem = cv2.imread('test.jpg')

face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

imagem_cinza = cv2.cvtColor(imagem, cv2.COLOR_BGR2GRAY)

detector_de_rostos = face_cascade.detectMultiScale(imagem_cinza, 1.3, 5)

for(inicio_x, inicio_y, rosto_w, rosto_h) in detector_de_rostos:
  fim_x = inicio_x + rosto_w
  fim_y = inicio_y + rosto_h

  cv2.rectangle(
      imagem,
      pt1 = (inicio_x, inicio_y),
      pt2 = (fim_x, fim_y),
      color = (255,0 , 0),
      thickness=2
      )

imagem_rgb = cv2.cvtColor(imagem, cv2.COLOR_BGR2RGB)
plt.imshow(imagem_rgb)
